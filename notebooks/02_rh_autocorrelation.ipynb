# %%
# %run '00_rh_settings.ipynb'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Зависимость значения следующего дня от значения предыдущего

# %% [markdown]
# Автокорреляцию оценим по графикам

# %%
ts_series=data.query("Stock == 'AAPL'")["Return"].dropna()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(ts_series);

# %%
plot_pacf(ts_series, lags=50);

# %%
from pandas.plotting import autocorrelation_plot

autocorr_plot = autocorrelation_plot(ts_series)
autocorr_plot.set_xlim(0, 50)
# Out:
# (0, 50)

# %%
from pandas.plotting import lag_plot
lag_plot(ts_series);
